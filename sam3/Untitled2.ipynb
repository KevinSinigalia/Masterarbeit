# %%
import cv2
import torch
from sam3 import SAM3VideoPredictor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import cv2
#       2 import torch
# ----> 3 from sam3 import SAM3VideoPredictor
#
# ImportError: cannot import name 'SAM3VideoPredictor' from 'sam3' (unknown location)
